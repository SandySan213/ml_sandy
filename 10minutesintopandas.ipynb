# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# ## Series: a one-dimensional labeled array holding data of any type
# ### such as integers, strings, Python objects etc.
# ## DataFrame: a two-dimensional data structure that holds data like a two-dimension array or a table with rows and columns.

# %%
dates = pd.date_range("20130101", periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[us]', freq='D')

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[us]
# C           float32
# D             int32
# E          category
# F               str
# dtype: object

# %%
df2.head()
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.tail()
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.index
# Out:
# Index([0, 1, 2, 3], dtype='int64')

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[us]
# C           float32
# D             int32
# E          category
# F               str
# dtype: object

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df2.describe()
# Out:
#          A                    B    C    D
# count  4.0                    4  4.0  4.0
# mean   1.0  2013-01-02 00:00:00  1.0  3.0
# min    1.0  2013-01-02 00:00:00  1.0  3.0
# 25%    1.0  2013-01-02 00:00:00  1.0  3.0
# 50%    1.0  2013-01-02 00:00:00  1.0  3.0
# 75%    1.0  2013-01-02 00:00:00  1.0  3.0
# max    1.0  2013-01-02 00:00:00  1.0  3.0
# std    0.0                  NaN  0.0  0.0

# %%
df2.T
# Out:
#                      0                    1                    2  \
# A                  1.0                  1.0                  1.0
# B  2013-01-02 00:00:00  2013-01-02 00:00:00  2013-01-02 00:00:00
# C                  1.0                  1.0                  1.0
# D                    3                    3                    3
# E                 test                train                 test
# F                  foo                  foo                  foo
#
#                      3
# A                  1.0
# B  2013-01-02 00:00:00
# C                  1.0
# D                    3
# E                train
# F                  foo

# %%
df2.sort_index(axis=1, ascending=False)
# Out:
#      F      E  D    C          B    A
# 0  foo   test  3  1.0 2013-01-02  1.0
# 1  foo  train  3  1.0 2013-01-02  1.0
# 2  foo   test  3  1.0 2013-01-02  1.0
# 3  foo  train  3  1.0 2013-01-02  1.0

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -1.275539  0.898634 -2.812913  0.439745
# 2013-01-02 -2.463475 -0.427516 -1.229710  0.320028
# 2013-01-03  1.540499 -1.718507  0.231569 -0.702733
# 2013-01-04 -0.021272 -1.072644 -1.476392  1.057249
# 2013-01-05  1.388730 -1.097477 -0.367168  0.637544
# 2013-01-06 -0.660237 -0.452058  0.731858  1.125855

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  0.439745 -2.812913  0.898634 -1.275539
# 2013-01-02  0.320028 -1.229710 -0.427516 -2.463475
# 2013-01-03 -0.702733  0.231569 -1.718507  1.540499
# 2013-01-04  1.057249 -1.476392 -1.072644 -0.021272
# 2013-01-05  0.637544 -0.367168 -1.097477  1.388730
# 2013-01-06  1.125855  0.731858 -0.452058 -0.660237

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2013-01-03  1.540499 -1.718507  0.231569 -0.702733
# 2013-01-05  1.388730 -1.097477 -0.367168  0.637544
# 2013-01-04 -0.021272 -1.072644 -1.476392  1.057249
# 2013-01-06 -0.660237 -0.452058  0.731858  1.125855
# 2013-01-02 -2.463475 -0.427516 -1.229710  0.320028
# 2013-01-01 -1.275539  0.898634 -2.812913  0.439745

# %%
df["A"]df[["B", "A"]]
# Out:
#   Cell In[23], line 1
#     df["A"]df[["B", "A"]]
#            ^
# SyntaxError: invalid syntax

# %%
df[["B", "A"]]
# Out:
#                    B         A
# 2013-01-01  0.898634 -1.275539
# 2013-01-02 -0.427516 -2.463475
# 2013-01-03 -1.718507  1.540499
# 2013-01-04 -1.072644 -0.021272
# 2013-01-05 -1.097477  1.388730
# 2013-01-06 -0.452058 -0.660237

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01 -1.275539  0.898634 -2.812913  0.439745
# 2013-01-02 -2.463475 -0.427516 -1.229710  0.320028
# 2013-01-03  1.540499 -1.718507  0.231569 -0.702733

# %%
df["20130102":"20130104"]
# Out:
#                    A         B         C         D
# 2013-01-02 -2.463475 -0.427516 -1.229710  0.320028
# 2013-01-03  1.540499 -1.718507  0.231569 -0.702733
# 2013-01-04 -0.021272 -1.072644 -1.476392  1.057249

# %%
df.loc[dates[0]]
# Out:
# A   -1.275539
# B    0.898634
# C   -2.812913
# D    0.439745
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2013-01-01 -1.275539  0.898634
# 2013-01-02 -2.463475 -0.427516
# 2013-01-03  1.540499 -1.718507
# 2013-01-04 -0.021272 -1.072644
# 2013-01-05  1.388730 -1.097477
# 2013-01-06 -0.660237 -0.452058

# %%
df.loc["20130102":"20130104", ["A", "B"]]
# Out:
#                    A         B
# 2013-01-02 -2.463475 -0.427516
# 2013-01-03  1.540499 -1.718507
# 2013-01-04 -0.021272 -1.072644

# %%
df.loc[dates[0], "A"]
# Out:
# np.float64(-1.2755394651172476)

# %%
df.at[dates[0], "A"]
# Out:
# np.float64(-1.2755394651172476)

# %%
df.iloc[3]
# Out:
# A   -0.021272
# B   -1.072644
# C   -1.476392
# D    1.057249
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04 -0.021272 -1.072644
# 2013-01-05  1.388730 -1.097477

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-03  1.540499 -1.718507  0.231569 -0.702733
# 2013-01-05  1.388730 -1.097477 -0.367168  0.637544

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01       NaN  0.898634       NaN  0.439745
# 2013-01-02       NaN       NaN       NaN  0.320028
# 2013-01-03  1.540499       NaN  0.231569       NaN
# 2013-01-04       NaN       NaN       NaN  1.057249
# 2013-01-05  1.388730       NaN       NaN  0.637544
# 2013-01-06       NaN       NaN  0.731858  1.125855

# %%
df2 = df.copy()

# %%
df2["E"] = ["one", "one", "two", "three", "four", "three"]

# %%
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -1.275539  0.898634 -2.812913  0.439745    one
# 2013-01-02 -2.463475 -0.427516 -1.229710  0.320028    one
# 2013-01-03  1.540499 -1.718507  0.231569 -0.702733    two
# 2013-01-04 -0.021272 -1.072644 -1.476392  1.057249  three
# 2013-01-05  1.388730 -1.097477 -0.367168  0.637544   four
# 2013-01-06 -0.660237 -0.452058  0.731858  1.125855  three

# %%
s1 = pd.Series(
   [1, 2, 3, 4, 5, 6],
   index=pd.date_range("20130102", periods=6))

# %%
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df.at[dates[0], "A"] = 0.2

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.200000  0.898634 -2.812913  0.439745
# 2013-01-02 -2.463475 -0.427516 -1.229710  0.320028
# 2013-01-03  1.540499 -1.718507  0.231569 -0.702733
# 2013-01-04 -0.021272 -1.072644 -1.476392  1.057249
# 2013-01-05  1.388730 -1.097477 -0.367168  0.637544
# 2013-01-06 -0.660237 -0.452058  0.731858  1.125855

# %%
df.iat[0, 1] = 0

# %%
df.loc[:, "D"] = np.array([5] * len(df))

# %%
df
# Out:
#                    A         B         C    D
# 2013-01-01  0.200000  0.000000 -2.812913  5.0
# 2013-01-02 -2.463475 -0.427516 -1.229710  5.0
# 2013-01-03  1.540499 -1.718507  0.231569  5.0
# 2013-01-04 -0.021272 -1.072644 -1.476392  5.0
# 2013-01-05  1.388730 -1.097477 -0.367168  5.0
# 2013-01-06 -0.660237 -0.452058  0.731858  5.0

# %%
df2 = df.copy()

# %%
df2[df2 > 0] = -df2

# %%
df2
# Out:
#                    A         B         C    D
# 2013-01-01 -0.200000  0.000000 -2.812913 -5.0
# 2013-01-02 -2.463475 -0.427516 -1.229710 -5.0
# 2013-01-03 -1.540499 -1.718507 -0.231569 -5.0
# 2013-01-04 -0.021272 -1.072644 -1.476392 -5.0
# 2013-01-05 -1.388730 -1.097477 -0.367168 -5.0
# 2013-01-06 -0.660237 -0.452058 -0.731858 -5.0

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])

# %%
df1
# Out:
#                    A         B         C    D   E
# 2013-01-01  0.200000  0.000000 -2.812913  5.0 NaN
# 2013-01-02 -2.463475 -0.427516 -1.229710  5.0 NaN
# 2013-01-03  1.540499 -1.718507  0.231569  5.0 NaN
# 2013-01-04 -0.021272 -1.072644 -1.476392  5.0 NaN

# %%
df1.loc[dates[0] : dates[1], "E"] = 1

# %%
df1
# Out:
#                    A         B         C    D    E
# 2013-01-01  0.200000  0.000000 -2.812913  5.0  1.0
# 2013-01-02 -2.463475 -0.427516 -1.229710  5.0  1.0
# 2013-01-03  1.540499 -1.718507  0.231569  5.0  NaN
# 2013-01-04 -0.021272 -1.072644 -1.476392  5.0  NaN

# %%
df1.dropna(how="any")
# Out:
#                    A         B         C    D    E
# 2013-01-01  0.200000  0.000000 -2.812913  5.0  1.0
# 2013-01-02 -2.463475 -0.427516 -1.229710  5.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C    D    E
# 2013-01-01  0.200000  0.000000 -2.812913  5.0  1.0
# 2013-01-02 -2.463475 -0.427516 -1.229710  5.0  1.0
# 2013-01-03  1.540499 -1.718507  0.231569  5.0  5.0
# 2013-01-04 -0.021272 -1.072644 -1.476392  5.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      E
# 2013-01-01  False  False  False  False  False
# 2013-01-02  False  False  False  False  False
# 2013-01-03  False  False  False  False   True
# 2013-01-04  False  False  False  False   True

# %%
df.mean()
# Out:
# A   -0.002626
# B   -0.794700
# C   -0.820459
# D    5.000000
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2013-01-01    0.596772
# 2013-01-02    0.219825
# 2013-01-03    1.263390
# 2013-01-04    0.607423
# 2013-01-05    1.231021
# 2013-01-06    1.154891
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.agg(lambda x: np.mean(x) * 5.6, axis=0)
# Out:
# A    -0.014705
# B    -4.450323
# C    -4.594571
# D    28.000000
# dtype: float64

# %%
df.transform(lambda x: x * 101.2)
# Out:
#                      A           B           C      D
# 2013-01-01   20.240000    0.000000 -284.666764  506.0
# 2013-01-02 -249.303677  -43.264649 -124.446638  506.0
# 2013-01-03  155.898545 -173.912922   23.434772  506.0
# 2013-01-04   -2.152738 -108.551586 -149.410823  506.0
# 2013-01-05  140.539431 -111.064639  -37.157359  506.0
# 2013-01-06  -66.816016  -45.748318   74.064015  506.0

# %%
s = pd.Series(np.random.randint(0, 7, size=10))
s
# Out:
# 0    0
# 1    1
# 2    5
# 3    6
# 4    1
# 5    0
# 6    6
# 7    3
# 8    1
# 9    2
# dtype: int64

# %%
s.value_counts()
# Out:
# 1    3
# 0    2
# 6    2
# 5    1
# 3    1
# 2    1
# Name: count, dtype: int64

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])

s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: str

# %%
df = pd.DataFrame(np.random.randn(10, 4))

# %%
df
# Out:
#           0         1         2         3
# 0 -1.860606  0.040105  0.486410  0.571808
# 1 -1.526856  0.461994  0.086870  0.669722
# 2  1.005465  1.258065  1.302949 -0.042505
# 3  0.380009  0.644479 -0.465045 -1.075834
# 4  0.707658  0.376292 -0.816293  1.000704
# 5  0.422413  1.410930 -1.460235  0.319095
# 6  0.157547 -1.239269  0.420141 -1.043709
# 7  1.509586 -0.350878  2.526537 -0.473101
# 8 -1.233084 -1.143891  0.006382 -0.570045
# 9 -0.020923 -1.958260  0.175126  0.051758

# %%
pieces = [df[:3], df[3:7], df[7:]]
pieces
# Out:
# [          0         1         2         3
#  0 -1.860606  0.040105  0.486410  0.571808
#  1 -1.526856  0.461994  0.086870  0.669722
#  2  1.005465  1.258065  1.302949 -0.042505,
#            0         1         2         3
#  3  0.380009  0.644479 -0.465045 -1.075834
#  4  0.707658  0.376292 -0.816293  1.000704
#  5  0.422413  1.410930 -1.460235  0.319095
#  6  0.157547 -1.239269  0.420141 -1.043709,
#            0         1         2         3
#  7  1.509586 -0.350878  2.526537 -0.473101
#  8 -1.233084 -1.143891  0.006382 -0.570045
#  9 -0.020923 -1.958260  0.175126  0.051758]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -1.860606  0.040105  0.486410  0.571808
# 1 -1.526856  0.461994  0.086870  0.669722
# 2  1.005465  1.258065  1.302949 -0.042505
# 3  0.380009  0.644479 -0.465045 -1.075834
# 4  0.707658  0.376292 -0.816293  1.000704
# 5  0.422413  1.410930 -1.460235  0.319095
# 6  0.157547 -1.239269  0.420141 -1.043709
# 7  1.509586 -0.350878  2.526537 -0.473101
# 8 -1.233084 -1.143891  0.006382 -0.570045
# 9 -0.020923 -1.958260  0.175126  0.051758

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
)

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one -0.110058 -0.537325
# 1  bar    one  1.074657  0.566303
# 2  foo    two  1.285760  0.869222
# 3  bar  three -0.107759 -0.208298
# 4  foo    two  0.227585  0.718766
# 5  bar    two  0.781683 -0.338159
# 6  foo    one -1.038089 -0.015570
# 7  foo  three -0.191271  0.055570

# %%
df.groupby("A")[["C", "D"]].sum()
# Out:
#             C         D
# A
# bar  1.748580  0.019846
# foo  0.173925  1.090662

# %%
df.groupby("A").sum()
# Out:
#                      B         C         D
# A
# bar        onethreetwo  1.748580  0.019846
# foo  onetwotwoonethree  0.173925  1.090662

# %%
df.groupby(["A", "B"]).sum()
# Out:
#                   C         D
# A   B
# bar one    1.074657  0.566303
#     three -0.107759 -0.208298
#     two    0.781683 -0.338159
# foo one   -1.148148 -0.552895
#     three -0.191271  0.055570
#     two    1.513344  1.587988

# %%
arrays = [
   ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
   ["one", "two", "one", "two", "one", "two", "one", "two"],
]

# %%
index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])
df
# Out:
#                      A         B
# first second
# bar   one    -0.361029  0.436468
#       two    -1.353373 -1.336375
# baz   one     0.613173 -1.159531
#       two    -1.814518 -0.928870
# foo   one    -1.060401  0.492800
#       two    -1.320721 -1.774247
# qux   one     0.916791  1.826421
#       two    -0.236941 -0.338314

# %%
df2 = df[:4]
df2
# Out:
#                      A         B
# first second
# bar   one    -0.361029  0.436468
#       two    -1.353373 -1.336375
# baz   one     0.613173 -1.159531
#       two    -1.814518 -0.928870

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A   -0.361029
#                B    0.436468
#        two     A   -1.353373
#                B   -1.336375
# baz    one     A    0.613173
#                B   -1.159531
#        two     A   -1.814518
#                B   -0.928870
# dtype: float64

# %%
stacked.unstack().unstack()
# Out:
#                A                   B
# second       one       two       one       two
# first
# bar    -0.361029 -1.353373  0.436468 -1.336375
# baz     0.613173 -1.814518 -1.159531 -0.928870

# %%
df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -2.036020 -1.255440
# 1     one  B  foo  0.286045 -0.805459
# 2     two  C  foo -1.755738 -1.331203
# 3   three  A  bar  1.198722 -2.298752
# 4     one  B  bar -1.081300  0.705802
# 5     one  C  bar  0.666104 -0.567038
# 6     two  A  foo -0.374173 -0.960639
# 7   three  B  foo  1.244148 -0.634245
# 8     one  C  foo -0.284732 -1.948653
# 9     one  A  bar  0.821343  0.236028
# 10    two  B  bar  2.067058 -1.224068
# 11  three  C  bar -0.164717 -1.088508

# %%
pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A  0.821343 -2.036020
#       B -1.081300  0.286045
#       C  0.666104 -0.284732
# three A  1.198722       NaN
#       B       NaN  1.244148
#       C -0.164717       NaN
# two   A       NaN -0.374173
#       B  2.067058       NaN
#       C       NaN -1.755738

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="s")
rng
# Out:
# DatetimeIndex(['2012-01-01 00:00:00', '2012-01-01 00:00:01',
#                '2012-01-01 00:00:02', '2012-01-01 00:00:03',
#                '2012-01-01 00:00:04', '2012-01-01 00:00:05',
#                '2012-01-01 00:00:06', '2012-01-01 00:00:07',
#                '2012-01-01 00:00:08', '2012-01-01 00:00:09',
#                '2012-01-01 00:00:10', '2012-01-01 00:00:11',
#                '2012-01-01 00:00:12', '2012-01-01 00:00:13',
#                '2012-01-01 00:00:14', '2012-01-01 00:00:15',
#                '2012-01-01 00:00:16', '2012-01-01 00:00:17',
#                '2012-01-01 00:00:18', '2012-01-01 00:00:19',
#                '2012-01-01 00:00:20', '2012-01-01 00:00:21',
#                '2012-01-01 00:00:22', '2012-01-01 00:00:23',
#                '2012-01-01 00:00:24', '2012-01-01 00:00:25',
#                '2012-01-01 00:00:26', '2012-01-01 00:00:27',
#                '2012-01-01 00:00:28', '2012-01-01 00:00:29',
#                '2012-01-01 00:00:30', '2012-01-01 00:00:31',
#                '2012-01-01 00:00:32', '2012-01-01 00:00:33',
#                '2012-01-01 00:00:34', '2012-01-01 00:00:35',
#                '2012-01-01 00:00:36', '2012-01-01 00:00:37',
#                '2012-01-01 00:00:38', '2012-01-01 00:00:39',
#                '2012-01-01 00:00:40', '2012-01-01 00:00:41',
#                '2012-01-01 00:00:42', '2012-01-01 00:00:43',
#                '2012-01-01 00:00:44', '2012-01-01 00:00:45',
#                '2012-01-01 00:00:46', '2012-01-01 00:00:47',
#                '2012-01-01 00:00:48', '2012-01-01 00:00:49',
#                '2012-01-01 00:00:50', '2012-01-01 00:00:51',
#                '2012-01-01 00:00:52', '2012-01-01 00:00:53',
#                '2012-01-01 00:00:54', '2012-01-01 00:00:55',
#                '2012-01-01 00:00:56', '2012-01-01 00:00:57',
#                '2012-01-01 00:00:58', '2012-01-01 00:00:59',
#                '2012-01-01 00:01:00', '2012-01-01 00:01:01',
#                '2012-01-01 00:01:02', '2012-01-01 00:01:03',
#                '2012-01-01 00:01:04', '2012-01-01 00:01:05',
#                '2012-01-01 00:01:06', '2012-01-01 00:01:07',
#                '2012-01-01 00:01:08', '2012-01-01 00:01:09',
#                '2012-01-01 00:01:10', '2012-01-01 00:01:11',
#                '2012-01-01 00:01:12', '2012-01-01 00:01:13',
#                '2012-01-01 00:01:14', '2012-01-01 00:01:15',
#                '2012-01-01 00:01:16', '2012-01-01 00:01:17',
#                '2012-01-01 00:01:18', '2012-01-01 00:01:19',
#                '2012-01-01 00:01:20', '2012-01-01 00:01:21',
#                '2012-01-01 00:01:22', '2012-01-01 00:01:23',
#                '2012-01-01 00:01:24', '2012-01-01 00:01:25',
#                '2012-01-01 00:01:26', '2012-01-01 00:01:27',
#                '2012-01-01 00:01:28', '2012-01-01 00:01:29',
#                '2012-01-01 00:01:30', '2012-01-01 00:01:31',
#                '2012-01-01 00:01:32', '2012-01-01 00:01:33',
#                '2012-01-01 00:01:34', '2012-01-01 00:01:35',
#                '2012-01-01 00:01:36', '2012-01-01 00:01:37',
#                '2012-01-01 00:01:38', '2012-01-01 00:01:39'],
#               dtype='datetime64[us]', freq='s')

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
ts
# Out:
# 2012-01-01 00:00:00    424
# 2012-01-01 00:00:01    241
# 2012-01-01 00:00:02    268
# 2012-01-01 00:00:03    178
# 2012-01-01 00:00:04    262
#                       ...
# 2012-01-01 00:01:35    380
# 2012-01-01 00:01:36    303
# 2012-01-01 00:01:37     27
# 2012-01-01 00:01:38    306
# 2012-01-01 00:01:39    386
# Freq: s, Length: 100, dtype: int64

# %%
sd= ts.resample("5Min").sum()
sd
# Out:
# 2012-01-01    24905
# Freq: 5min, dtype: int64

# %%
ts
# Out:
# 2012-01-01 00:00:00    424
# 2012-01-01 00:00:01    241
# 2012-01-01 00:00:02    268
# 2012-01-01 00:00:03    178
# 2012-01-01 00:00:04    262
#                       ...
# 2012-01-01 00:01:35    380
# 2012-01-01 00:01:36    303
# 2012-01-01 00:01:37     27
# 2012-01-01 00:01:38    306
# 2012-01-01 00:01:39    386
# Freq: s, Length: 100, dtype: int64

# %%
rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)
ts
# Out:
# 2012-03-06   -1.235666
# 2012-03-07    0.698273
# 2012-03-08   -0.474902
# 2012-03-09   -0.318306
# 2012-03-10   -0.355679
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")

# %%
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -1.235666
# 2012-03-07 00:00:00+00:00    0.698273
# 2012-03-08 00:00:00+00:00   -0.474902
# 2012-03-09 00:00:00+00:00   -0.318306
# 2012-03-10 00:00:00+00:00   -0.355679
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# 2012-03-05 19:00:00-05:00   -1.235666
# 2012-03-06 19:00:00-05:00    0.698273
# 2012-03-07 19:00:00-05:00   -0.474902
# 2012-03-08 19:00:00-05:00   -0.318306
# 2012-03-09 19:00:00-05:00   -0.355679
# dtype: float64

# %%
rng
# Out:
# DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10'],
#               dtype='datetime64[us]', freq='D')

# %%
rng + pd.offsets.BusinessDay(5)
# Out:
# DatetimeIndex(['2012-03-13', '2012-03-14', '2012-03-15', '2012-03-16',
#                '2012-03-16'],
#               dtype='datetime64[us]', freq=None)

# %%
df = pd.DataFrame(
    {"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)

# %%
df["grade"] = df["raw_grade"].astype("category")

# %%
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, str): ['a', 'b', 'e']

# %%
new_categories = ["very good", "good", "very bad"]

# %%
df["grade"] = df["grade"].cat.rename_categories(new_categories)
df
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 1   2         b       good
# 2   3         b       good
# 3   4         a  very good
# 4   5         a  very good
# 5   6         e   very bad

# %%
df["grade"] = df["grade"].cat.set_categories(
    ["very bad", "bad", "medium", "good", "very good"]
)

# %%
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, str): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
df.groupby("grade", observed=False).size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.close("all")

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

# %%
ts = ts.cumsum()

# %%
ts
# Out:
# 2000-01-01    -1.336398
# 2000-01-02    -1.769940
# 2000-01-03    -1.975222
# 2000-01-04    -2.879552
# 2000-01-05    -3.512717
#                 ...
# 2002-09-22   -29.039814
# 2002-09-23   -28.802840
# 2002-09-24   -27.614489
# 2002-09-25   -26.124427
# 2002-09-26   -26.499490
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot();

# %%
df = pd.DataFrame(
    np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)
df = df.cumsum()
plt.figure();
df.plot();
plt.legend(loc='best');

# %%
df = pd.DataFrame(np.random.randint(0, 5, (10, 5)))
df.to_csv("foo.csv")

# %%
pd.read_csv("foo.csv")
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  1  0  0  1  3
# 1           1  0  3  0  4  0
# 2           2  1  0  4  0  1
# 3           3  0  4  4  0  2
# 4           4  4  1  3  1  0
# 5           5  3  3  2  1  3
# 6           6  2  1  1  2  2
# 7           7  0  3  1  3  1
# 8           8  3  3  2  2  4
# 9           9  0  3  4  0  4

# %%
df.to_parquet("foo.parquet")

# %%
df.to_excel("foo.xlsx", sheet_name="Sheet1")
