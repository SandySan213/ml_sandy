# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np

# %%
plt.plot();

# %%
plt.plot([1,2,3,4,5]);

# %%
# method 1
x=[1,2,3,4,5]
y=[11,22,33,44,55]
plt.plot(x,y)

# %%
# method 2
fig = plt.figure()
ax = fig.add_axes([1,1,.5,.5])
ax.plot(x,y)
plt.show()

# %%
# method 3 ( recommended )
fig, ax = plt.subplots()
ax.plot(x,y);
